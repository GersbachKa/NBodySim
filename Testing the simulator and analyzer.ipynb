# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.insert(0,'nbodysim')
from nbodysim.simulator import Simulator
from nbodysim.analyzer import Analyzer
import numpy as np

from bokeh.io import push_notebook, show, output_notebook
from bokeh.plotting import figure

# %%
help(Simulator)

# %%
G=6.67259 * (10**-11)

MEarth = 6*(10**24)
MMoon = 7.35*(10**22)
REarth = 6*(10**6)
RMoon = 1.7*(10**6)
orbitR = 3.63*(10**8)
orbitV = np.sqrt((G*MEarth)/orbitR)

#fix Linear momentum problem
#total lin momentum = MMoon * orbitV
#fixed: MMoon*orbitV = MMoon*(V) + MEarth*(V)
fixV = (MMoon*orbitV)/(MMoon+MEarth) 

ra = (REarth+RMoon+orbitR)*1.2

sim = Simulator(name='Earth-Moon',notebook=True)
sim.addMass(name='Earth',mass=MEarth,radius=REarth,yVel=-fixV,color=(0,200,150))
sim.addMass(name='Moon',mass=MMoon,radius=RMoon,xPos=orbitR,yVel=orbitV-fixV,color=(150,150,150))
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
sim.play(dt=2,numSteps=int(60*60/2),save=True,pause=0.01,
         plotFirst=True,axes=('x','y'),plotRange=(-ra,ra))
# Out:
#   <div class="bk-root" id="3795e6da-dfea-4b58-a3d5-97c96ee79b47" data-root-id="2000"></div>
# Halted

# %%
ana = Analyzer(path = '/home/kyle/GWA/NBodySim/Earth-Moon')
#ana = Analyzer(simulator=sim)
fig = ana.plot(['Earth','Earth'],['x','y'])
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2138">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="9205d72a-ecff-49ab-a832-d277fcba2009" data-root-id="2139"></div>

# %%
sim2 = Simulator(True)
sim2.addMass('M1',10**12,1,0,0,0,0,-.3,0)
sim2.addMass('M2',1,.1,40,0,0,-.1,0,0)
sim2.setPlot(plotTitle='Test',plotRange=(-50,50))
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2310">Loading BokehJS ...</span>
#     </div>

# %%
sim2.play(.001,1000,pause=.1)
# Out:
#   <div class="bk-root" id="9d2e2ca8-e027-40cb-8e54-c8d07cdd4cd4" data-root-id="2311"></div>
# Halted

# %%
m1 = sim2.getMass('M1')
m2 = sim2.getMass('M2')
print(m1.getVelocities())
print(m2.getVelocities())
# Out:
# (-1.8858353231802956e-12, -0.2999999999996922, 0.0)
# (1.7858353231802995, -0.464701300586955, 0.0)
