# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.insert(0,'nbodysim')
from nbodysim.simulator import Simulator
from nbodysim.analyzer import Analyzer
import numpy as np

from bokeh.io import push_notebook, show, output_notebook
from bokeh.plotting import figure

# %%
G=6.67259 * (10**-11)

MEarth = 6*(10**24)
MMoon = 7.35*(10**22)
REarth = 6*(10**6)
RMoon = 1.7*(10**6)
orbitR = 3.63*(10**8)
orbitV = np.sqrt((G*MEarth)/orbitR)

#fix Linear momentum problem
#total lin momentum = MMoon * orbitV
#fixed: MMoon*orbitV = MMoon*(V) + MEarth*(V)
fixV = (MMoon*orbitV)/(MMoon+MEarth) 

ra = (REarth+RMoon+orbitR)*1.2

sim = Simulator(name='Earth-Moon',notebook=True)
sim.addMass(name='Earth',mass=MEarth,radius=REarth,yVel=-fixV)
sim.addMass(name='Moon',mass=MMoon,radius=RMoon,xPos=orbitR,yVel=orbitV-fixV)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
help(Simulator)

# %%
sim.play(dt=2,numSteps=int(60*60/2),save=True,pause=0,
         plotFirst=True,axes=('x','y'),plotRange=(-ra,ra))
# Out:
#   <div class="bk-root" id="4a371196-15b5-463f-be6d-c7cfc00afbe9" data-root-id="1002"></div>
# Halted

# %%
ana = Analyzer(path = '/home/kyle/GWA/NBodySim/Earth-Moon')
#ana = Analyzer(simulator=sim)
fig = ana.plot(['Earth','Earth'],['x','y'])
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4711">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="46256dac-4d41-4903-bf96-452e72210b47" data-root-id="4712"></div>

# %%
sim2 = Simulator(True)
sim2.addMass('M1',10**12,1,0,0,0,0,-.3,0)
sim2.addMass('M2',1,.1,40,0,0,-.1,0,0)
sim2.setPlot(plotTitle='Test',plotRange=(-50,50))

# %%
sim2.play(.001,1000,pause=.1)

# %%
m1 = sim2.getMass('M1')
m2 = sim2.getMass('M2')
print(m1.getVelocities())
print(m2.getVelocities())

# %%
path = '/home/kyle/GWA/NBodySim/Earth-Moon'
a = Analyzer(path=path)
b = Analyzer(simulator=sim)

# %%
a.plotVsTime([('Earth','x')])

# %%
[a[0] for a in data]

# %%
for mass in a.massData:
    print(mass[0] == 'Mini-moon')
